# %%
import os
import cv2
import numpy as np
import platform 
import numpy as np
import pandas as pd;
import matplotlib.pyplot as plt
import argparse
import glob
import os, json
import os.path as osp
import sys, random
import imgviz
import numpy as np
#import labelme
import seaborn as sns
import warnings

from skimage.feature import local_binary_pattern

warnings.filterwarnings('ignore')

# %%
def processes(data):
    return  abs((data - np.min(data)) / (np.max(data) - np.min(data)))

# %%
pathImage = '/Users/niyanqin/PycharmProjects/LearningDL/AOI/zhiyong_fabric/dataset/resizedata/243/1616050068681.jpg'

# %%
img = cv2.imread(pathImage, cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img, 'gray')
plt.show()

# %%
img2 = processes(img)
plt.figure(figsize=(20,14))
plt.imshow(img2, 'gray')
plt.show()

# %%
img3 = local_binary_pattern(img, 8, 2.0, 'ror')
plt.figure(figsize=(20,14))
plt.imshow(img3, 'gray')
plt.show()
