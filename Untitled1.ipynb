# %%
from Reference.segmentation_models.segmentation_models.models import fpn
# Out:
# Segmentation Models: using `keras` framework.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32724/1778697369.py in <module>
# ----> 1 from Reference.segmentation_models.segmentation_models.models import fpn
#
# ~\PycharmProjects\pythonProject\AOI\ICPR2023\Reference\segmentation_models\__init__.py in <module>
# ----> 1 from .segmentation_models import *
#
# ~\PycharmProjects\pythonProject\AOI\ICPR2023\Reference\segmentation_models\segmentation_models\__init__.py in <module>
#     106 from . import losses
#     107 from . import metrics
# --> 108 from . import utils
#     109
#     110 # wrap segmentation models with framework modules
#
# ~\PycharmProjects\pythonProject\AOI\ICPR2023\Reference\segmentation_models\segmentation_models\utils.py in <module>
#       1 """ Utility functions for segmentation models """
#       2
# ----> 3 from keras_applications import get_submodules_from_kwargs
#       4 from . import inject_global_submodules
#       5
#
# ModuleNotFoundError: No module named 'keras_applications'

# %%
from tensorflow.keras.layers import Activation, Conv2D, MaxPooling2D, BatchNormalization, Input, DepthwiseConv2D, add,Dropout, AveragePooling2D, Concatenate, Layer, InputSpec
from tensorflow.keras.models import Model
from tensorflow.python.keras.utils import conv_utils
import tensorflow as tf
from keras.models import *
from keras.layers import *
from keras.utils import conv_utils

from keras.utils.data_utils import get_file
from keras.utils.conv_utils import normalize_data_format


class BilinearUpsampling(Layer):

    def __init__(self, upsampling=(2, 2), data_format=None, **kwargs):
        super(BilinearUpsampling, self).__init__(**kwargs)
        self.data_format = normalize_data_format(data_format)
        self.upsampling = conv_utils.normalize_tuple(upsampling, 2, 'size')
        self.input_spec = InputSpec(ndim=4)

    def compute_output_shape(self, input_shape):
        height = self.upsampling[0] * \
                 input_shape[1] if input_shape[1] is not None else None
        width = self.upsampling[1] * \
                input_shape[2] if input_shape[2] is not None else None
        return (input_shape[0], height, width, input_shape[3])

    def call(self, inputs):
        # .tf
        return tf.compat.v1.image.resize_bilinear(inputs, (int(inputs.shape[1] * self.upsampling[0]),
                                                 int(inputs.shape[2] * self.upsampling[1])))

    def get_config(self):

        config = {'size': self.upsampling, 'data_format': self.data_format}
        base_config = super(BilinearUpsampling, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

def xception_downsample_block(x, channels, top_relu=False):
    ##separable conv1
    if top_relu:
        x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(channels, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    ##separable conv2
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(channels, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    ##separable conv3
    x = DepthwiseConv2D((3, 3), strides=(2, 2), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(channels, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    return x


def res_xception_downsample_block(x, channels):
    res = Conv2D(channels, (1, 1), strides=(2, 2), padding="same", use_bias=False)(x)
    res = BatchNormalization()(res)
    x = xception_downsample_block(x, channels)
    x = add([x, res])
    return x


def xception_block(x, channels):
    ##separable conv1
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(channels, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)

    ##separable conv2
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(channels, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)

    ##separable conv3
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(channels, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    return x


def res_xception_block(x, channels):
    res = x
    x = xception_block(x, channels)
    x = add([x, res])
    return x


def aspp(x, input_shape, out_stride):
    b0 = Conv2D(256, (1, 1), padding="same", use_bias=False)(x)
    b0 = BatchNormalization()(b0)
    b0 = Activation("relu")(b0)

    b1 = DepthwiseConv2D((3, 3), dilation_rate=(6, 6), padding="same", use_bias=False)(x)
    b1 = BatchNormalization()(b1)
    b1 = Activation("relu")(b1)
    b1 = Conv2D(256, (1, 1), padding="same", use_bias=False)(b1)
    b1 = BatchNormalization()(b1)
    b1 = Activation("relu")(b1)

    b2 = DepthwiseConv2D((3, 3), dilation_rate=(12, 12), padding="same", use_bias=False)(x)
    b2 = BatchNormalization()(b2)
    b2 = Activation("relu")(b2)
    b2 = Conv2D(256, (1, 1), padding="same", use_bias=False)(b2)
    b2 = BatchNormalization()(b2)
    b2 = Activation("relu")(b2)

    b3 = DepthwiseConv2D((3, 3), dilation_rate=(12, 12), padding="same", use_bias=False)(x)
    b3 = BatchNormalization()(b3)
    b3 = Activation("relu")(b3)
    b3 = Conv2D(256, (1, 1), padding="same", use_bias=False)(b3)
    b3 = BatchNormalization()(b3)
    b3 = Activation("relu")(b3)

    out_shape = int(input_shape[0] / out_stride)
    b4 = AveragePooling2D(pool_size=(out_shape, out_shape))(x)
    b4 = Conv2D(256, (1, 1), padding="same", use_bias=False)(b4)
    b4 = BatchNormalization()(b4)
    b4 = Activation("relu")(b4)
    b4 = BilinearUpsampling((out_shape, out_shape))(b4)

    x = Concatenate()([b4, b0, b1, b2, b3])
    return x


def DeeplabV3_plus(nClasses=21, input_height=512, input_width=512, out_stride=16):
    img_input = Input(shape=(input_height, input_width, 3))
    x = Conv2D(32, (3, 3), strides=(2, 2), padding="same", use_bias=False)(img_input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(64, (3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = res_xception_downsample_block(x, 128)

    res = Conv2D(256, (1, 1), strides=(2, 2), padding="same", use_bias=False)(x)
    res = BatchNormalization()(res)
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(256, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(256, (1, 1), padding="same", use_bias=False)(x)
    skip = BatchNormalization()(x)
    x = Activation("relu")(skip)
    x = DepthwiseConv2D((3, 3), strides=(2, 2), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(256, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = add([x, res])

    x = xception_downsample_block(x, 728, top_relu=True)

    for i in range(16):
        x = res_xception_block(x, 728)

    res = Conv2D(1024, (1, 1), padding="same", use_bias=False)(x)
    res = BatchNormalization()(res)
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(728, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(1024, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(1024, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = add([x, res])

    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(1536, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(1536, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Conv2D(2048, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    # aspp
    x = aspp(x, (input_height, input_width, 3), out_stride)
    x = Conv2D(256, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Dropout(0.9)(x)

    ##decoder
    x = BilinearUpsampling((4, 4))(x)
    dec_skip = Conv2D(48, (1, 1), padding="same", use_bias=False)(skip)
    dec_skip = BatchNormalization()(dec_skip)
    dec_skip = Activation("relu")(dec_skip)
    x = Concatenate()([x, dec_skip])

    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(256, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = DepthwiseConv2D((3, 3), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(256, (1, 1), padding="same", use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(nClasses, (1, 1), padding="same")(x)
    x = BilinearUpsampling((4, 4))(x)
#     outputHeight = Model(img_input, x).output_shape[1]
#     outputWidth = Model(img_input, x).output_shape[2]
#     x = (Reshape((outputHeight * outputWidth, nClasses)))(x)
#     x = Activation('softmax')(x)
    model = Model(img_input, x)
    return model

# %%
model = DeeplabV3_plus(nClasses=2, input_height=256, input_width=256, out_stride=16)
model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_463 (Conv2D)            (None, 128, 128, 32  864         ['input_7[0][0]']
#                                 )
#
#  batch_normalization_864 (Batch  (None, 128, 128, 32  128        ['conv2d_463[0][0]']
#  Normalization)                 )
#
#  activation_466 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_864[0][0]']
#                                 )
#
#  conv2d_464 (Conv2D)            (None, 128, 128, 64  18432       ['activation_466[0][0]']
#                                 )
#
#  batch_normalization_865 (Batch  (None, 128, 128, 64  256        ['conv2d_464[0][0]']
#  Normalization)                 )
#
#  activation_467 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_865[0][0]']
#                                 )
#
#  depthwise_conv2d_406 (Depthwis  (None, 128, 128, 64  576        ['activation_467[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_867 (Batch  (None, 128, 128, 64  256        ['depthwise_conv2d_406[0][0]']
#  Normalization)                 )
#
#  conv2d_466 (Conv2D)            (None, 128, 128, 12  8192        ['batch_normalization_867[0][0]']
#                                 8)
#
#  batch_normalization_868 (Batch  (None, 128, 128, 12  512        ['conv2d_466[0][0]']
#  Normalization)                 8)
#
#  activation_468 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_868[0][0]']
#                                 8)
#
#  depthwise_conv2d_407 (Depthwis  (None, 128, 128, 12  1152       ['activation_468[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_869 (Batch  (None, 128, 128, 12  512        ['depthwise_conv2d_407[0][0]']
#  Normalization)                 8)
#
#  conv2d_467 (Conv2D)            (None, 128, 128, 12  16384       ['batch_normalization_869[0][0]']
#                                 8)
#
#  batch_normalization_870 (Batch  (None, 128, 128, 12  512        ['conv2d_467[0][0]']
#  Normalization)                 8)
#
#  activation_469 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_870[0][0]']
#                                 8)
#
#  depthwise_conv2d_408 (Depthwis  (None, 64, 64, 128)  1152       ['activation_469[0][0]']
#  eConv2D)
#
#  batch_normalization_871 (Batch  (None, 64, 64, 128)  512        ['depthwise_conv2d_408[0][0]']
#  Normalization)
#
#  conv2d_468 (Conv2D)            (None, 64, 64, 128)  16384       ['batch_normalization_871[0][0]']
#
#  conv2d_465 (Conv2D)            (None, 64, 64, 128)  8192        ['activation_467[0][0]']
#
#  batch_normalization_872 (Batch  (None, 64, 64, 128)  512        ['conv2d_468[0][0]']
#  Normalization)
#
#  batch_normalization_866 (Batch  (None, 64, 64, 128)  512        ['conv2d_465[0][0]']
#  Normalization)
#
#  add_114 (Add)                  (None, 64, 64, 128)  0           ['batch_normalization_872[0][0]',
#                                                                   'batch_normalization_866[0][0]']
#
#  activation_470 (Activation)    (None, 64, 64, 128)  0           ['add_114[0][0]']
#
#  depthwise_conv2d_409 (Depthwis  (None, 64, 64, 128)  1152       ['activation_470[0][0]']
#  eConv2D)
#
#  batch_normalization_874 (Batch  (None, 64, 64, 128)  512        ['depthwise_conv2d_409[0][0]']
#  Normalization)
#
#  conv2d_470 (Conv2D)            (None, 64, 64, 256)  32768       ['batch_normalization_874[0][0]']
#  batch_normalization_875 (Batch  (None, 64, 64, 256)  1024       ['conv2d_470[0][0]']
#  Normalization)
#
#  activation_471 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_875[0][0]']
#
#  depthwise_conv2d_410 (Depthwis  (None, 64, 64, 256)  2304       ['activation_471[0][0]']
#  eConv2D)
#
#  batch_normalization_876 (Batch  (None, 64, 64, 256)  1024       ['depthwise_conv2d_410[0][0]']
#  Normalization)
#
#  conv2d_471 (Conv2D)            (None, 64, 64, 256)  65536       ['batch_normalization_876[0][0]']
#
#  batch_normalization_877 (Batch  (None, 64, 64, 256)  1024       ['conv2d_471[0][0]']
#  Normalization)
#
#  activation_472 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_877[0][0]']
#
#  depthwise_conv2d_411 (Depthwis  (None, 32, 32, 256)  2304       ['activation_472[0][0]']
#  eConv2D)
#
#  batch_normalization_878 (Batch  (None, 32, 32, 256)  1024       ['depthwise_conv2d_411[0][0]']
#  Normalization)
#
#  conv2d_472 (Conv2D)            (None, 32, 32, 256)  65536       ['batch_normalization_878[0][0]']
#
#  conv2d_469 (Conv2D)            (None, 32, 32, 256)  32768       ['add_114[0][0]']
#
#  batch_normalization_879 (Batch  (None, 32, 32, 256)  1024       ['conv2d_472[0][0]']
#  Normalization)
#
#  batch_normalization_873 (Batch  (None, 32, 32, 256)  1024       ['conv2d_469[0][0]']
#  Normalization)
#
#  add_115 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_879[0][0]',
#                                                                   'batch_normalization_873[0][0]']
#
#  activation_473 (Activation)    (None, 32, 32, 256)  0           ['add_115[0][0]']
#
#  depthwise_conv2d_412 (Depthwis  (None, 32, 32, 256)  2304       ['activation_473[0][0]']
#  eConv2D)
#
#  batch_normalization_880 (Batch  (None, 32, 32, 256)  1024       ['depthwise_conv2d_412[0][0]']
#  Normalization)
#
#  conv2d_473 (Conv2D)            (None, 32, 32, 728)  186368      ['batch_normalization_880[0][0]']
#
#  batch_normalization_881 (Batch  (None, 32, 32, 728)  2912       ['conv2d_473[0][0]']
#  Normalization)
#
#  activation_474 (Activation)    (None, 32, 32, 728)  0           ['batch_normalization_881[0][0]']
#
#  depthwise_conv2d_413 (Depthwis  (None, 32, 32, 728)  6552       ['activation_474[0][0]']
#  eConv2D)
#
#  batch_normalization_882 (Batch  (None, 32, 32, 728)  2912       ['depthwise_conv2d_413[0][0]']
#  Normalization)
#
#  conv2d_474 (Conv2D)            (None, 32, 32, 728)  529984      ['batch_normalization_882[0][0]']
#
#  batch_normalization_883 (Batch  (None, 32, 32, 728)  2912       ['conv2d_474[0][0]']
#  Normalization)
#
#  activation_475 (Activation)    (None, 32, 32, 728)  0           ['batch_normalization_883[0][0]']
#
#  depthwise_conv2d_414 (Depthwis  (None, 16, 16, 728)  6552       ['activation_475[0][0]']
#  eConv2D)
#
#  batch_normalization_884 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_414[0][0]']
#  Normalization)
#
#  conv2d_475 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_884[0][0]']
#
#  batch_normalization_885 (Batch  (None, 16, 16, 728)  2912       ['conv2d_475[0][0]']
#  Normalization)
#
#  activation_476 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_885[0][0]']
#
#  depthwise_conv2d_415 (Depthwis  (None, 16, 16, 728)  6552       ['activation_476[0][0]']
#  eConv2D)
#
#  batch_normalization_886 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_415[0][0]']
#  Normalization)
#
#  conv2d_476 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_886[0][0]']
#
#  batch_normalization_887 (Batch  (None, 16, 16, 728)  2912       ['conv2d_476[0][0]']
#  Normalization)
#
#  activation_477 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_887[0][0]']
#
#  depthwise_conv2d_416 (Depthwis  (None, 16, 16, 728)  6552       ['activation_477[0][0]']
#  eConv2D)
#
#  batch_normalization_888 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_416[0][0]']
#  Normalization)
#
#  conv2d_477 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_888[0][0]']
#
#  batch_normalization_889 (Batch  (None, 16, 16, 728)  2912       ['conv2d_477[0][0]']
#  Normalization)
#
#  activation_478 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_889[0][0]']
#
#  depthwise_conv2d_417 (Depthwis  (None, 16, 16, 728)  6552       ['activation_478[0][0]']
#  eConv2D)
#
#  batch_normalization_890 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_417[0][0]']
#  Normalization)
#
#  conv2d_478 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_890[0][0]']
#
#  batch_normalization_891 (Batch  (None, 16, 16, 728)  2912       ['conv2d_478[0][0]']
#  Normalization)
#
#  add_116 (Add)                  (None, 16, 16, 728)  0           ['batch_normalization_891[0][0]',
#                                                                   'batch_normalization_885[0][0]']
#
#  activation_479 (Activation)    (None, 16, 16, 728)  0           ['add_116[0][0]']
#
#  depthwise_conv2d_418 (Depthwis  (None, 16, 16, 728)  6552       ['activation_479[0][0]']
#  eConv2D)
#
#  batch_normalization_892 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_418[0][0]']
#  Normalization)
#
#  conv2d_479 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_892[0][0]']
#
#  batch_normalization_893 (Batch  (None, 16, 16, 728)  2912       ['conv2d_479[0][0]']
#  Normalization)
#
#  activation_480 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_893[0][0]']
#
#  depthwise_conv2d_419 (Depthwis  (None, 16, 16, 728)  6552       ['activation_480[0][0]']
#  eConv2D)
#
#  batch_normalization_894 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_419[0][0]']
#  Normalization)
#
#  conv2d_480 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_894[0][0]']
#
#  batch_normalization_895 (Batch  (None, 16, 16, 728)  2912       ['conv2d_480[0][0]']
#  Normalization)
#
#  activation_481 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_895[0][0]']
#
#  depthwise_conv2d_420 (Depthwis  (None, 16, 16, 728)  6552       ['activation_481[0][0]']
#  eConv2D)
#
#  batch_normalization_896 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_420[0][0]']
#  Normalization)
#
#  conv2d_481 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_896[0][0]']
#
#  batch_normalization_897 (Batch  (None, 16, 16, 728)  2912       ['conv2d_481[0][0]']
#  Normalization)
#
#  add_117 (Add)                  (None, 16, 16, 728)  0           ['batch_normalization_897[0][0]',
#                                                                   'add_116[0][0]']
#
#  activation_482 (Activation)    (None, 16, 16, 728)  0           ['add_117[0][0]']
#
#  depthwise_conv2d_421 (Depthwis  (None, 16, 16, 728)  6552       ['activation_482[0][0]']
#  eConv2D)
#
#  batch_normalization_898 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_421[0][0]']
#  Normalization)
#
#  conv2d_482 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_898[0][0]']
#
#  batch_normalization_899 (Batch  (None, 16, 16, 728)  2912       ['conv2d_482[0][0]']
#  Normalization)
#
#  activation_483 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_899[0][0]']
#
#  depthwise_conv2d_422 (Depthwis  (None, 16, 16, 728)  6552       ['activation_483[0][0]']
#  eConv2D)
#
#  batch_normalization_900 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_422[0][0]']
#  Normalization)
#
#  conv2d_483 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_900[0][0]']
#
#  batch_normalization_901 (Batch  (None, 16, 16, 728)  2912       ['conv2d_483[0][0]']
#  Normalization)
#
#  activation_484 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_901[0][0]']
#
#  depthwise_conv2d_423 (Depthwis  (None, 16, 16, 728)  6552       ['activation_484[0][0]']
#  eConv2D)
#
#  batch_normalization_902 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_423[0][0]']
#  Normalization)
#
#  conv2d_484 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_902[0][0]']
#
#  batch_normalization_903 (Batch  (None, 16, 16, 728)  2912       ['conv2d_484[0][0]']
#  Normalization)
#
#  add_118 (Add)                  (None, 16, 16, 728)  0           ['batch_normalization_903[0][0]',
#                                                                   'add_117[0][0]']
#
#  activation_485 (Activation)    (None, 16, 16, 728)  0           ['add_118[0][0]']
#
#  depthwise_conv2d_424 (Depthwis  (None, 16, 16, 728)  6552       ['activation_485[0][0]']
#  eConv2D)
#
#  batch_normalization_904 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_424[0][0]']
#  Normalization)
#
#  conv2d_485 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_904[0][0]']
#
#  batch_normalization_905 (Batch  (None, 16, 16, 728)  2912       ['conv2d_485[0][0]']
#  Normalization)
#
#  activation_486 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_905[0][0]']
#
#  depthwise_conv2d_425 (Depthwis  (None, 16, 16, 728)  6552       ['activation_486[0][0]']
#  eConv2D)
#
#  batch_normalization_906 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_425[0][0]']
#  Normalization)
#
#  conv2d_486 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_906[0][0]']
#
#  batch_normalization_907 (Batch  (None, 16, 16, 728)  2912       ['conv2d_486[0][0]']
#  Normalization)
#
#  activation_487 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_907[0][0]']
#
#  depthwise_conv2d_426 (Depthwis  (None, 16, 16, 728)  6552       ['activation_487[0][0]']
#  eConv2D)
#
#  batch_normalization_908 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_426[0][0]']
#  Normalization)
#
#  conv2d_487 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_908[0][0]']
#
#  batch_normalization_909 (Batch  (None, 16, 16, 728)  2912       ['conv2d_487[0][0]']
#  Normalization)
#
#  add_119 (Add)                  (None, 16, 16, 728)  0           ['batch_normalization_909[0][0]',
#                                                                   'add_118[0][0]']
#
#  activation_488 (Activation)    (None, 16, 16, 728)  0           ['add_119[0][0]']
#
#  depthwise_conv2d_427 (Depthwis  (None, 16, 16, 728)  6552       ['activation_488[0][0]']
#  eConv2D)
#  batch_normalization_910 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_427[0][0]']
#  Normalization)
#
#  conv2d_488 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_910[0][0]']
#
#  batch_normalization_911 (Batch  (None, 16, 16, 728)  2912       ['conv2d_488[0][0]']
#  Normalization)
#
#  activation_489 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_911[0][0]']
#
#  depthwise_conv2d_428 (Depthwis  (None, 16, 16, 728)  6552       ['activation_489[0][0]']
#  eConv2D)
#
#  batch_normalization_912 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_428[0][0]']
#  Normalization)
#
#  conv2d_489 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_912[0][0]']
#
#  batch_normalization_913 (Batch  (None, 16, 16, 728)  2912       ['conv2d_489[0][0]']
#  Normalization)
#
#  activation_490 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_913[0][0]']
#
#  depthwise_conv2d_429 (Depthwis  (None, 16, 16, 728)  6552       ['activation_490[0][0]']
#  eConv2D)
#
#  batch_normalization_914 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_429[0][0]']
#  Normalization)
#
#  conv2d_490 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_914[0][0]']
#
#  batch_normalization_915 (Batch  (None, 16, 16, 728)  2912       ['conv2d_490[0][0]']
#  Normalization)
#
#  add_120 (Add)                  (None, 16, 16, 728)  0           ['batch_normalization_915[0][0]',
#                                                                   'add_119[0][0]']
#
#  activation_491 (Activation)    (None, 16, 16, 728)  0           ['add_120[0][0]']
#
#  depthwise_conv2d_430 (Depthwis  (None, 16, 16, 728)  6552       ['activation_491[0][0]']
#  eConv2D)
#
#  batch_normalization_916 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_430[0][0]']
#  Normalization)
#
#  conv2d_491 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_916[0][0]']
#
#  batch_normalization_917 (Batch  (None, 16, 16, 728)  2912       ['conv2d_491[0][0]']
#  Normalization)
#
#  activation_492 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_917[0][0]']
#
#  depthwise_conv2d_431 (Depthwis  (None, 16, 16, 728)  6552       ['activation_492[0][0]']
#  eConv2D)
#
#  batch_normalization_918 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_431[0][0]']
#  Normalization)
#
#  conv2d_492 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_918[0][0]']
#
#  batch_normalization_919 (Batch  (None, 16, 16, 728)  2912       ['conv2d_492[0][0]']
#  Normalization)
#
#  activation_493 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_919[0][0]']
#
#  depthwise_conv2d_432 (Depthwis  (None, 16, 16, 728)  6552       ['activation_493[0][0]']
#  eConv2D)
#
#  batch_normalization_920 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_432[0][0]']
#  Normalization)
#
#  conv2d_493 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_920[0][0]']
#
#  batch_normalization_921 (Batch  (None, 16, 16, 728)  2912       ['conv2d_493[0][0]']
#  Normalization)
#
#  add_121 (Add)                  (None, 16, 16, 728)  0           ['batch_normalization_921[0][0]',
#                                                                   'add_120[0][0]']
#
#  activation_494 (Activation)    (None, 16, 16, 728)  0           ['add_121[0][0]']
#
#  depthwise_conv2d_433 (Depthwis  (None, 16, 16, 728)  6552       ['activation_494[0][0]']
#  eConv2D)
#
#  batch_normalization_922 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_433[0][0]']
#  Normalization)
#
#  conv2d_494 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_922[0][0]']
#
#  batch_normalization_923 (Batch  (None, 16, 16, 728)  2912       ['conv2d_494[0][0]']
#  Normalization)
#
#  activation_495 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_923[0][0]']
#
#  depthwise_conv2d_434 (Depthwis  (None, 16, 16, 728)  6552       ['activation_495[0][0]']
#  eConv2D)
#
#  batch_normalization_924 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_434[0][0]']
#  Normalization)
#
#  conv2d_495 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_924[0][0]']
#
#  batch_normalization_925 (Batch  (None, 16, 16, 728)  2912       ['conv2d_495[0][0]']
#  Normalization)
#
#  activation_496 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_925[0][0]']
#
#  depthwise_conv2d_435 (Depthwis  (None, 16, 16, 728)  6552       ['activation_496[0][0]']
#  eConv2D)
#
#  batch_normalization_926 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_435[0][0]']
#  Normalization)
#
#  conv2d_496 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_926[0][0]']
#
#  batch_normalization_927 (Batch  (None, 16, 16, 728)  2912       ['conv2d_496[0][0]']
#  Normalization)
#
#  add_122 (Add)                  (None, 16, 16, 728)  0           ['batch_normalization_927[0][0]',
#                                                                   'add_121[0][0]']
#
#  activation_497 (Activation)    (None, 16, 16, 728)  0           ['add_122[0][0]']
#
#  depthwise_conv2d_436 (Depthwis  (None, 16, 16, 728)  6552       ['activation_497[0][0]']
#  eConv2D)
#
#  batch_normalization_928 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_436[0][0]']
#  Normalization)
#
#  conv2d_497 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_928[0][0]']
#
#  batch_normalization_929 (Batch  (None, 16, 16, 728)  2912       ['conv2d_497[0][0]']
#  Normalization)
#
#  activation_498 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_929[0][0]']
#
#  depthwise_conv2d_437 (Depthwis  (None, 16, 16, 728)  6552       ['activation_498[0][0]']
#  eConv2D)
#
#  batch_normalization_930 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_437[0][0]']
#  Normalization)
#
#  conv2d_498 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_930[0][0]']
#
#  batch_normalization_931 (Batch  (None, 16, 16, 728)  2912       ['conv2d_498[0][0]']
#  Normalization)
#
#  activation_499 (Activation)    (None, 16, 16, 728)  0           ['batch_normalization_931[0][0]']
#
#  depthwise_conv2d_438 (Depthwis  (None, 16, 16, 728)  6552       ['activation_499[0][0]']
#  eConv2D)
#
#  batch_normalization_932 (Batch  (None, 16, 16, 728)  2912       ['depthwise_conv2d_438[0][0]']
#  Normalization)
#
#  conv2d_499 (Conv2D)            (None, 16, 16, 728)  529984      ['batch_normalization_932[0][0]']
#
# ...
#  Normalization)                 )
#
#  activation_528 (Activation)    (None, 16, 16, 1536  0           ['batch_normalization_992[0][0]']
#                                 )
#
#  depthwise_conv2d_468 (Depthwis  (None, 16, 16, 1536  13824      ['activation_528[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_993 (Batch  (None, 16, 16, 1536  6144       ['depthwise_conv2d_468[0][0]']
#  Normalization)                 )
#
#  conv2d_530 (Conv2D)            (None, 16, 16, 2048  3145728     ['batch_normalization_993[0][0]']
#                                 )
#
#  batch_normalization_994 (Batch  (None, 16, 16, 2048  8192       ['conv2d_530[0][0]']
#  Normalization)                 )
#
#  activation_529 (Activation)    (None, 16, 16, 2048  0           ['batch_normalization_994[0][0]']
#                                 )
#
#  depthwise_conv2d_469 (Depthwis  (None, 16, 16, 2048  18432      ['activation_529[0][0]']
#  eConv2D)                       )
#
#  depthwise_conv2d_470 (Depthwis  (None, 16, 16, 2048  18432      ['activation_529[0][0]']
#  eConv2D)                       )
#
#  depthwise_conv2d_471 (Depthwis  (None, 16, 16, 2048  18432      ['activation_529[0][0]']
#  eConv2D)                       )
#
#  average_pooling2d_6 (AveragePo  (None, 1, 1, 2048)  0           ['activation_529[0][0]']
#  oling2D)
#
#  batch_normalization_996 (Batch  (None, 16, 16, 2048  8192       ['depthwise_conv2d_469[0][0]']
#  Normalization)                 )
#
#  batch_normalization_998 (Batch  (None, 16, 16, 2048  8192       ['depthwise_conv2d_470[0][0]']
#  Normalization)                 )
#
#  batch_normalization_1000 (Batc  (None, 16, 16, 2048  8192       ['depthwise_conv2d_471[0][0]']
#  hNormalization)                )
#
#  conv2d_535 (Conv2D)            (None, 1, 1, 256)    524288      ['average_pooling2d_6[0][0]']
#
#  activation_531 (Activation)    (None, 16, 16, 2048  0           ['batch_normalization_996[0][0]']
#                                 )
#
#  activation_533 (Activation)    (None, 16, 16, 2048  0           ['batch_normalization_998[0][0]']
#                                 )
#
#  activation_535 (Activation)    (None, 16, 16, 2048  0           ['batch_normalization_1000[0][0]'
#                                 )                                ]
#
#  batch_normalization_1002 (Batc  (None, 1, 1, 256)   1024        ['conv2d_535[0][0]']
#  hNormalization)
#
#  conv2d_531 (Conv2D)            (None, 16, 16, 256)  524288      ['activation_529[0][0]']
#
#  conv2d_532 (Conv2D)            (None, 16, 16, 256)  524288      ['activation_531[0][0]']
#
#  conv2d_533 (Conv2D)            (None, 16, 16, 256)  524288      ['activation_533[0][0]']
#
#  conv2d_534 (Conv2D)            (None, 16, 16, 256)  524288      ['activation_535[0][0]']
#
#  activation_537 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_1002[0][0]'
#                                                                  ]
#
#  batch_normalization_995 (Batch  (None, 16, 16, 256)  1024       ['conv2d_531[0][0]']
#  Normalization)
#
#  batch_normalization_997 (Batch  (None, 16, 16, 256)  1024       ['conv2d_532[0][0]']
#  Normalization)
#
#  batch_normalization_999 (Batch  (None, 16, 16, 256)  1024       ['conv2d_533[0][0]']
#  Normalization)
#
#  batch_normalization_1001 (Batc  (None, 16, 16, 256)  1024       ['conv2d_534[0][0]']
#  hNormalization)
#
#  bilinear_upsampling_16 (Biline  (None, 16, 16, 256)  0          ['activation_537[0][0]']
#  arUpsampling)
#
#  activation_530 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_995[0][0]']
#
#  activation_532 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_997[0][0]']
#
#  activation_534 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_999[0][0]']
#
#  activation_536 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_1001[0][0]'
#                                                                  ]
#
#  concatenate_10 (Concatenate)   (None, 16, 16, 1280  0           ['bilinear_upsampling_16[0][0]',
#                                 )                                 'activation_530[0][0]',
#                                                                   'activation_532[0][0]',
#                                                                   'activation_534[0][0]',
#                                                                   'activation_536[0][0]']
#
#  conv2d_536 (Conv2D)            (None, 16, 16, 256)  327680      ['concatenate_10[0][0]']
#
#  batch_normalization_1003 (Batc  (None, 16, 16, 256)  1024       ['conv2d_536[0][0]']
#  hNormalization)
#
#  activation_538 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_1003[0][0]'
#                                                                  ]
#
#  conv2d_537 (Conv2D)            (None, 64, 64, 48)   12288       ['batch_normalization_877[0][0]']
#
#  dropout_5 (Dropout)            (None, 16, 16, 256)  0           ['activation_538[0][0]']
#
#  batch_normalization_1004 (Batc  (None, 64, 64, 48)  192         ['conv2d_537[0][0]']
#  hNormalization)
#
#  bilinear_upsampling_17 (Biline  (None, 64, 64, 256)  0          ['dropout_5[0][0]']
#  arUpsampling)
#
#  activation_539 (Activation)    (None, 64, 64, 48)   0           ['batch_normalization_1004[0][0]'
#                                                                  ]
#
#  concatenate_11 (Concatenate)   (None, 64, 64, 304)  0           ['bilinear_upsampling_17[0][0]',
#                                                                   'activation_539[0][0]']
#
#  depthwise_conv2d_472 (Depthwis  (None, 64, 64, 304)  2736       ['concatenate_11[0][0]']
#  eConv2D)
#
#  batch_normalization_1005 (Batc  (None, 64, 64, 304)  1216       ['depthwise_conv2d_472[0][0]']
#  hNormalization)
#
#  activation_540 (Activation)    (None, 64, 64, 304)  0           ['batch_normalization_1005[0][0]'
#                                                                  ]
#
#  conv2d_538 (Conv2D)            (None, 64, 64, 256)  77824       ['activation_540[0][0]']
#
#  batch_normalization_1006 (Batc  (None, 64, 64, 256)  1024       ['conv2d_538[0][0]']
#  hNormalization)
#
#  activation_541 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_1006[0][0]'
#                                                                  ]
#
#  depthwise_conv2d_473 (Depthwis  (None, 64, 64, 256)  2304       ['activation_541[0][0]']
#  eConv2D)
#
#  batch_normalization_1007 (Batc  (None, 64, 64, 256)  1024       ['depthwise_conv2d_473[0][0]']
#  hNormalization)
#
#  activation_542 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_1007[0][0]'
#                                                                  ]
#
#  conv2d_539 (Conv2D)            (None, 64, 64, 256)  65536       ['activation_542[0][0]']
#
#  batch_normalization_1008 (Batc  (None, 64, 64, 256)  1024       ['conv2d_539[0][0]']
#  hNormalization)
#
#  activation_543 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_1008[0][0]'
#                                                                  ]
#
#  conv2d_540 (Conv2D)            (None, 64, 64, 2)    514         ['activation_543[0][0]']
#
#  bilinear_upsampling_18 (Biline  (None, 256, 256, 2)  0          ['conv2d_540[0][0]']
#  arUpsampling)
#
# ==================================================================================================
# Total params: 41,064,050
# Trainable params: 40,862,706
# Non-trainable params: 201,344
# __________________________________________________________________________________________________

# %%
#coding=utf-8
import tensorflow as tf
import keras 
from keras.models import *
from keras.layers import *

def conv_block(inputx, filters):
    out = Conv2D(filters, kernel_size=(3,3), strides=1, padding='same')(inputx)
    out = BatchNormalization()(out)
    out = Activation('relu')(out)
    out = Conv2D(filters, kernel_size=(3,3), strides=1, padding='same')(out)
    out = BatchNormalization()(out)
    out = Activation('relu')(out)
    return out

def up_conv(inputx, filters):
    out = UpSampling2D()(inputx)
    out = Conv2D(filters, kernel_size=(3,3), strides=1, padding='same')(out)
    out = BatchNormalization()(out)
    out = Activation('relu')(out)
    return out

def Attention_block(input1, input2, filters):
    g1 = Conv2D(filters, kernel_size=1, strides=1, padding='same')(input1)
    g1 = BatchNormalization()(g1)
    x1 = Conv2D(filters, kernel_size=1, strides=1, padding='same')(input2)
    x1 = BatchNormalization()(x1)
    psi = Activation('relu')(add([g1, x1]))
    psi = Conv2D(filters, kernel_size=1, strides=1, padding='same')(psi)
    psi = BatchNormalization()(psi)
    psi = Activation('sigmoid')(psi)
    
    out = multiply([input2, psi])
    print(out.shape)
    return out

def Recurrent_block(inputx, channel, t=2):
    for i in range(t):
        if i == 0:
            x = Conv2D(channel, kernel_size=(3, 3), strides=1, padding='same')(inputx)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
        out = Conv2D(channel, kernel_size=(3, 3), strides=1, padding='same')(add([x, x]))
        out = BatchNormalization()(out)
        out = Activation('relu')(out)
    return out

def RRCNN_block(inputx, channel, t=2):
    x1 = Conv2D(channel, kernel_size=(1, 1), strides=1, padding='same')(inputx)
    x2 = Recurrent_block(x1, channel, t=t)
    x2 = Recurrent_block(x2, channel, t=t)
    out = add([x1, x2])
    return out



def R2AttUNet(nClasses, input_height=224, input_width=224):
    # """
    #Residual Recuurent Block with attention Unet
    #Implementation : https://github.com/LeeJunHyun/Image_Segmentation
    #"""
    inputs = Input(shape=(input_height, input_width, 3))
    t = 2
    n1 = 32
    filters = [n1, n1 * 2, n1 * 4, n1 * 8, n1 * 16]

    e1 = RRCNN_block(inputs, filters[0], t=t)

    e2 = MaxPooling2D(strides=2)(e1)
    e2 = RRCNN_block(e2, filters[1], t=t)

    e3 = MaxPooling2D(strides=2)(e2)
    e3 = RRCNN_block(e3, filters[2], t=t)

    e4 = MaxPooling2D(strides=2)(e3)
    e4 = RRCNN_block(e4, filters[3], t=t)

    e5 = MaxPooling2D(strides=2)(e4)
    e5 = RRCNN_block(e5, filters[4], t=t)

    d5 = up_conv(e5, filters[3])
    x4 =  Attention_block(d5, e4, filters[3])
    d5 = Concatenate()([x4, d5])
    d5 = conv_block(d5, filters[3])

    d4 = up_conv(d5, filters[2])
    x3 =  Attention_block(d4, e3, filters[2])
    d4 = Concatenate()([x3, d4])
    d4 = conv_block(d4, filters[2])

    d3 = up_conv(d4, filters[1])
    x2 =  Attention_block(d3, e2, filters[1])
    d3 = Concatenate()([x2, d3])
    d3 = conv_block(d3, filters[1])

    d2 = up_conv(d3, filters[0])
    x1 =  Attention_block(d2, e1, filters[0])
    d2 = Concatenate()([x1, d2])
    d2 = conv_block(d2, filters[0])

    out = Conv2D(nClasses, (3, 3), padding='same')(d2)


    model = Model(inputs=inputs, outputs=out)

    return model

# %%
model = R2AttUNet(nClasses=2, input_height=256, input_width=256)
model.summary()
# Out:
# (None, 32, 32, 256)
# (None, 64, 64, 128)
# (None, 128, 128, 64)
# (None, 256, 256, 32)
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_700 (Conv2D)            (None, 256, 256, 32  128         ['input_11[0][0]']
#                                 )
#
#  conv2d_701 (Conv2D)            (None, 256, 256, 32  9248        ['conv2d_700[0][0]']
#                                 )
#
#  batch_normalization_1151 (Batc  (None, 256, 256, 32  128        ['conv2d_701[0][0]']
#  hNormalization)                )
#
#  activation_678 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1151[0][0]'
#                                 )                                ]
#
#  add_218 (Add)                  (None, 256, 256, 32  0           ['activation_678[0][0]',
#                                 )                                 'activation_678[0][0]']
#
#  conv2d_703 (Conv2D)            (None, 256, 256, 32  9248        ['add_218[0][0]']
#                                 )
#
#  batch_normalization_1153 (Batc  (None, 256, 256, 32  128        ['conv2d_703[0][0]']
#  hNormalization)                )
#
#  activation_680 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1153[0][0]'
#                                 )                                ]
#
#  conv2d_704 (Conv2D)            (None, 256, 256, 32  9248        ['activation_680[0][0]']
#                                 )
#
#  batch_normalization_1154 (Batc  (None, 256, 256, 32  128        ['conv2d_704[0][0]']
#  hNormalization)                )
#
#  activation_681 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1154[0][0]'
#                                 )                                ]
#
#  add_220 (Add)                  (None, 256, 256, 32  0           ['activation_681[0][0]',
#                                 )                                 'activation_681[0][0]']
#
#  conv2d_706 (Conv2D)            (None, 256, 256, 32  9248        ['add_220[0][0]']
#                                 )
#
#  batch_normalization_1156 (Batc  (None, 256, 256, 32  128        ['conv2d_706[0][0]']
#  hNormalization)                )
#
#  activation_683 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1156[0][0]'
#                                 )                                ]
#
#  add_221 (Add)                  (None, 256, 256, 32  0           ['conv2d_700[0][0]',
#                                 )                                 'activation_683[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 128, 128, 32  0          ['add_221[0][0]']
#  )                              )
#
#  conv2d_707 (Conv2D)            (None, 128, 128, 64  2112        ['max_pooling2d_12[0][0]']
#                                 )
#
#  conv2d_708 (Conv2D)            (None, 128, 128, 64  36928       ['conv2d_707[0][0]']
#                                 )
#
#  batch_normalization_1157 (Batc  (None, 128, 128, 64  256        ['conv2d_708[0][0]']
#  hNormalization)                )
#
#  activation_684 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1157[0][0]'
#                                 )                                ]
#
#  add_223 (Add)                  (None, 128, 128, 64  0           ['activation_684[0][0]',
#                                 )                                 'activation_684[0][0]']
#
#  conv2d_710 (Conv2D)            (None, 128, 128, 64  36928       ['add_223[0][0]']
#                                 )
#
#  batch_normalization_1159 (Batc  (None, 128, 128, 64  256        ['conv2d_710[0][0]']
#  hNormalization)                )
#
#  activation_686 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1159[0][0]'
#                                 )                                ]
#
#  conv2d_711 (Conv2D)            (None, 128, 128, 64  36928       ['activation_686[0][0]']
#                                 )
#
#  batch_normalization_1160 (Batc  (None, 128, 128, 64  256        ['conv2d_711[0][0]']
#  hNormalization)                )
#
#  activation_687 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1160[0][0]'
#                                 )                                ]
#
#  add_225 (Add)                  (None, 128, 128, 64  0           ['activation_687[0][0]',
#                                 )                                 'activation_687[0][0]']
#
#  conv2d_713 (Conv2D)            (None, 128, 128, 64  36928       ['add_225[0][0]']
#                                 )
#
#  batch_normalization_1162 (Batc  (None, 128, 128, 64  256        ['conv2d_713[0][0]']
#  hNormalization)                )
#
#  activation_689 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1162[0][0]'
#                                 )                                ]
#
#  add_226 (Add)                  (None, 128, 128, 64  0           ['conv2d_707[0][0]',
#                                 )                                 'activation_689[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 64, 64, 64)  0           ['add_226[0][0]']
#  )
#
#  conv2d_714 (Conv2D)            (None, 64, 64, 128)  8320        ['max_pooling2d_13[0][0]']
#
#  conv2d_715 (Conv2D)            (None, 64, 64, 128)  147584      ['conv2d_714[0][0]']
#
#  batch_normalization_1163 (Batc  (None, 64, 64, 128)  512        ['conv2d_715[0][0]']
#  hNormalization)
#
#  activation_690 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1163[0][0]'
#                                                                  ]
#
#  add_228 (Add)                  (None, 64, 64, 128)  0           ['activation_690[0][0]',
#                                                                   'activation_690[0][0]']
#
#  conv2d_717 (Conv2D)            (None, 64, 64, 128)  147584      ['add_228[0][0]']
#
#  batch_normalization_1165 (Batc  (None, 64, 64, 128)  512        ['conv2d_717[0][0]']
#  hNormalization)
#
#  activation_692 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1165[0][0]'
#                                                                  ]
#
#  conv2d_718 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_692[0][0]']
#
#  batch_normalization_1166 (Batc  (None, 64, 64, 128)  512        ['conv2d_718[0][0]']
#  hNormalization)
#
#  activation_693 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1166[0][0]'
#                                                                  ]
#
#  add_230 (Add)                  (None, 64, 64, 128)  0           ['activation_693[0][0]',
#                                                                   'activation_693[0][0]']
#
#  conv2d_720 (Conv2D)            (None, 64, 64, 128)  147584      ['add_230[0][0]']
#
#  batch_normalization_1168 (Batc  (None, 64, 64, 128)  512        ['conv2d_720[0][0]']
#  hNormalization)
#
#  activation_695 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1168[0][0]'
#                                                                  ]
#
#  add_231 (Add)                  (None, 64, 64, 128)  0           ['conv2d_714[0][0]',
#                                                                   'activation_695[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 32, 32, 128)  0          ['add_231[0][0]']
#  )
#
#  conv2d_721 (Conv2D)            (None, 32, 32, 256)  33024       ['max_pooling2d_14[0][0]']
#
#  conv2d_722 (Conv2D)            (None, 32, 32, 256)  590080      ['conv2d_721[0][0]']
#
#  batch_normalization_1169 (Batc  (None, 32, 32, 256)  1024       ['conv2d_722[0][0]']
#  hNormalization)
#
#  activation_696 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1169[0][0]'
#                                                                  ]
#
#  add_233 (Add)                  (None, 32, 32, 256)  0           ['activation_696[0][0]',
#                                                                   'activation_696[0][0]']
#
#  conv2d_724 (Conv2D)            (None, 32, 32, 256)  590080      ['add_233[0][0]']
#
#  batch_normalization_1171 (Batc  (None, 32, 32, 256)  1024       ['conv2d_724[0][0]']
#  hNormalization)
#
#  activation_698 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1171[0][0]'
#                                                                  ]
#
#  conv2d_725 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_698[0][0]']
#
#  batch_normalization_1172 (Batc  (None, 32, 32, 256)  1024       ['conv2d_725[0][0]']
#  hNormalization)
#
#  activation_699 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1172[0][0]'
#                                                                  ]
#
#  add_235 (Add)                  (None, 32, 32, 256)  0           ['activation_699[0][0]',
#                                                                   'activation_699[0][0]']
#
#  conv2d_727 (Conv2D)            (None, 32, 32, 256)  590080      ['add_235[0][0]']
#
#  batch_normalization_1174 (Batc  (None, 32, 32, 256)  1024       ['conv2d_727[0][0]']
#  hNormalization)
#
#  activation_701 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1174[0][0]'
#                                                                  ]
#
#  add_236 (Add)                  (None, 32, 32, 256)  0           ['conv2d_721[0][0]',
#                                                                   'activation_701[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 16, 16, 256)  0          ['add_236[0][0]']
#  )
#
#  conv2d_728 (Conv2D)            (None, 16, 16, 512)  131584      ['max_pooling2d_15[0][0]']
#
#  conv2d_729 (Conv2D)            (None, 16, 16, 512)  2359808     ['conv2d_728[0][0]']
#
#  batch_normalization_1175 (Batc  (None, 16, 16, 512)  2048       ['conv2d_729[0][0]']
#  hNormalization)
#
#  activation_702 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_1175[0][0]'
#                                                                  ]
#
#  add_238 (Add)                  (None, 16, 16, 512)  0           ['activation_702[0][0]',
#                                                                   'activation_702[0][0]']
#
#  conv2d_731 (Conv2D)            (None, 16, 16, 512)  2359808     ['add_238[0][0]']
#
#  batch_normalization_1177 (Batc  (None, 16, 16, 512)  2048       ['conv2d_731[0][0]']
#  hNormalization)
#
#  activation_704 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_1177[0][0]'
#                                                                  ]
#
#  conv2d_732 (Conv2D)            (None, 16, 16, 512)  2359808     ['activation_704[0][0]']
#
#  batch_normalization_1178 (Batc  (None, 16, 16, 512)  2048       ['conv2d_732[0][0]']
#  hNormalization)
#
#  activation_705 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_1178[0][0]'
#                                                                  ]
#
#  add_240 (Add)                  (None, 16, 16, 512)  0           ['activation_705[0][0]',
#                                                                   'activation_705[0][0]']
#
#  conv2d_734 (Conv2D)            (None, 16, 16, 512)  2359808     ['add_240[0][0]']
#
#  batch_normalization_1180 (Batc  (None, 16, 16, 512)  2048       ['conv2d_734[0][0]']
#  hNormalization)
#
#  activation_707 (Activation)    (None, 16, 16, 512)  0           ['batch_normalization_1180[0][0]'
#                                                                  ]
#
#  add_241 (Add)                  (None, 16, 16, 512)  0           ['conv2d_728[0][0]',
#                                                                   'activation_707[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 32, 32, 512)  0          ['add_241[0][0]']
#
#  conv2d_735 (Conv2D)            (None, 32, 32, 256)  1179904     ['up_sampling2d_9[0][0]']
#
#  batch_normalization_1181 (Batc  (None, 32, 32, 256)  1024       ['conv2d_735[0][0]']
#  hNormalization)
#
#  activation_708 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1181[0][0]'
#                                                                  ]
#
#  conv2d_736 (Conv2D)            (None, 32, 32, 256)  65792       ['activation_708[0][0]']
#
#  conv2d_737 (Conv2D)            (None, 32, 32, 256)  65792       ['add_236[0][0]']
#
#  batch_normalization_1182 (Batc  (None, 32, 32, 256)  1024       ['conv2d_736[0][0]']
#  hNormalization)
#
#  batch_normalization_1183 (Batc  (None, 32, 32, 256)  1024       ['conv2d_737[0][0]']
#  hNormalization)
#
#  add_242 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_1182[0][0]'
#                                                                  , 'batch_normalization_1183[0][0]
#                                                                  ']
#
#  activation_709 (Activation)    (None, 32, 32, 256)  0           ['add_242[0][0]']
#
#  conv2d_738 (Conv2D)            (None, 32, 32, 256)  65792       ['activation_709[0][0]']
#
#  batch_normalization_1184 (Batc  (None, 32, 32, 256)  1024       ['conv2d_738[0][0]']
#  hNormalization)
#
#  activation_710 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1184[0][0]'
#                                                                  ]
#
#  multiply_9 (Multiply)          (None, 32, 32, 256)  0           ['add_236[0][0]',
#                                                                   'activation_710[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 32, 32, 512)  0           ['multiply_9[0][0]',
#                                                                   'activation_708[0][0]']
#
#  conv2d_739 (Conv2D)            (None, 32, 32, 256)  1179904     ['concatenate_20[0][0]']
#
#  batch_normalization_1185 (Batc  (None, 32, 32, 256)  1024       ['conv2d_739[0][0]']
#  hNormalization)
#
#  activation_711 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1185[0][0]'
#                                                                  ]
#
#  conv2d_740 (Conv2D)            (None, 32, 32, 256)  590080      ['activation_711[0][0]']
#
#  batch_normalization_1186 (Batc  (None, 32, 32, 256)  1024       ['conv2d_740[0][0]']
#  hNormalization)
#
#  activation_712 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_1186[0][0]'
#                                                                  ]
#
#  up_sampling2d_10 (UpSampling2D  (None, 64, 64, 256)  0          ['activation_712[0][0]']
#  )
#
#  conv2d_741 (Conv2D)            (None, 64, 64, 128)  295040      ['up_sampling2d_10[0][0]']
#
#  batch_normalization_1187 (Batc  (None, 64, 64, 128)  512        ['conv2d_741[0][0]']
#  hNormalization)
#
#  activation_713 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1187[0][0]'
#                                                                  ]
#
#  conv2d_742 (Conv2D)            (None, 64, 64, 128)  16512       ['activation_713[0][0]']
#
#  conv2d_743 (Conv2D)            (None, 64, 64, 128)  16512       ['add_231[0][0]']
#
#  batch_normalization_1188 (Batc  (None, 64, 64, 128)  512        ['conv2d_742[0][0]']
#  hNormalization)
#
#  batch_normalization_1189 (Batc  (None, 64, 64, 128)  512        ['conv2d_743[0][0]']
#  hNormalization)
#
#  add_243 (Add)                  (None, 64, 64, 128)  0           ['batch_normalization_1188[0][0]'
#                                                                  , 'batch_normalization_1189[0][0]
#                                                                  ']
#
#  activation_714 (Activation)    (None, 64, 64, 128)  0           ['add_243[0][0]']
#
#  conv2d_744 (Conv2D)            (None, 64, 64, 128)  16512       ['activation_714[0][0]']
#
#  batch_normalization_1190 (Batc  (None, 64, 64, 128)  512        ['conv2d_744[0][0]']
#  hNormalization)
#  activation_715 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1190[0][0]'
#                                                                  ]
#
#  multiply_10 (Multiply)         (None, 64, 64, 128)  0           ['add_231[0][0]',
#                                                                   'activation_715[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 64, 64, 256)  0           ['multiply_10[0][0]',
#                                                                   'activation_713[0][0]']
#
#  conv2d_745 (Conv2D)            (None, 64, 64, 128)  295040      ['concatenate_21[0][0]']
#
#  batch_normalization_1191 (Batc  (None, 64, 64, 128)  512        ['conv2d_745[0][0]']
#  hNormalization)
#
#  activation_716 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1191[0][0]'
#                                                                  ]
#
#  conv2d_746 (Conv2D)            (None, 64, 64, 128)  147584      ['activation_716[0][0]']
#
#  batch_normalization_1192 (Batc  (None, 64, 64, 128)  512        ['conv2d_746[0][0]']
#  hNormalization)
#
#  activation_717 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_1192[0][0]'
#                                                                  ]
#
#  up_sampling2d_11 (UpSampling2D  (None, 128, 128, 12  0          ['activation_717[0][0]']
#  )                              8)
#
#  conv2d_747 (Conv2D)            (None, 128, 128, 64  73792       ['up_sampling2d_11[0][0]']
#                                 )
#
#  batch_normalization_1193 (Batc  (None, 128, 128, 64  256        ['conv2d_747[0][0]']
#  hNormalization)                )
#
#  activation_718 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1193[0][0]'
#                                 )                                ]
#
#  conv2d_748 (Conv2D)            (None, 128, 128, 64  4160        ['activation_718[0][0]']
#                                 )
#
#  conv2d_749 (Conv2D)            (None, 128, 128, 64  4160        ['add_226[0][0]']
#                                 )
#
#  batch_normalization_1194 (Batc  (None, 128, 128, 64  256        ['conv2d_748[0][0]']
#  hNormalization)                )
#
#  batch_normalization_1195 (Batc  (None, 128, 128, 64  256        ['conv2d_749[0][0]']
#  hNormalization)                )
#
#  add_244 (Add)                  (None, 128, 128, 64  0           ['batch_normalization_1194[0][0]'
#                                 )                                , 'batch_normalization_1195[0][0]
#                                                                  ']
#
#  activation_719 (Activation)    (None, 128, 128, 64  0           ['add_244[0][0]']
#                                 )
#
#  conv2d_750 (Conv2D)            (None, 128, 128, 64  4160        ['activation_719[0][0]']
#                                 )
#
#  batch_normalization_1196 (Batc  (None, 128, 128, 64  256        ['conv2d_750[0][0]']
#  hNormalization)                )
#
#  activation_720 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1196[0][0]'
#                                 )                                ]
#
#  multiply_11 (Multiply)         (None, 128, 128, 64  0           ['add_226[0][0]',
#                                 )                                 'activation_720[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 128, 128, 12  0           ['multiply_11[0][0]',
#                                 8)                                'activation_718[0][0]']
#
#  conv2d_751 (Conv2D)            (None, 128, 128, 64  73792       ['concatenate_22[0][0]']
#                                 )
#
#  batch_normalization_1197 (Batc  (None, 128, 128, 64  256        ['conv2d_751[0][0]']
#  hNormalization)                )
#
#  activation_721 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1197[0][0]'
#                                 )                                ]
#
#  conv2d_752 (Conv2D)            (None, 128, 128, 64  36928       ['activation_721[0][0]']
#                                 )
#  batch_normalization_1198 (Batc  (None, 128, 128, 64  256        ['conv2d_752[0][0]']
#  hNormalization)                )
#
#  activation_722 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_1198[0][0]'
#                                 )                                ]
#
#  up_sampling2d_12 (UpSampling2D  (None, 256, 256, 64  0          ['activation_722[0][0]']
#  )                              )
#
#  conv2d_753 (Conv2D)            (None, 256, 256, 32  18464       ['up_sampling2d_12[0][0]']
#                                 )
#
#  batch_normalization_1199 (Batc  (None, 256, 256, 32  128        ['conv2d_753[0][0]']
#  hNormalization)                )
#
#  activation_723 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1199[0][0]'
#                                 )                                ]
#
#  conv2d_754 (Conv2D)            (None, 256, 256, 32  1056        ['activation_723[0][0]']
#                                 )
#
#  conv2d_755 (Conv2D)            (None, 256, 256, 32  1056        ['add_221[0][0]']
#                                 )
#
#  batch_normalization_1200 (Batc  (None, 256, 256, 32  128        ['conv2d_754[0][0]']
#  hNormalization)                )
#
#  batch_normalization_1201 (Batc  (None, 256, 256, 32  128        ['conv2d_755[0][0]']
#  hNormalization)                )
#
#  add_245 (Add)                  (None, 256, 256, 32  0           ['batch_normalization_1200[0][0]'
#                                 )                                , 'batch_normalization_1201[0][0]
#                                                                  ']
#
#  activation_724 (Activation)    (None, 256, 256, 32  0           ['add_245[0][0]']
#                                 )
#
#  conv2d_756 (Conv2D)            (None, 256, 256, 32  1056        ['activation_724[0][0]']
#                                 )
#
#  batch_normalization_1202 (Batc  (None, 256, 256, 32  128        ['conv2d_756[0][0]']
#  hNormalization)                )
#
#  activation_725 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1202[0][0]'
#                                 )                                ]
#
#  multiply_12 (Multiply)         (None, 256, 256, 32  0           ['add_221[0][0]',
#                                 )                                 'activation_725[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 256, 256, 64  0           ['multiply_12[0][0]',
#                                 )                                 'activation_723[0][0]']
#
#  conv2d_757 (Conv2D)            (None, 256, 256, 32  18464       ['concatenate_23[0][0]']
#                                 )
#
#  batch_normalization_1203 (Batc  (None, 256, 256, 32  128        ['conv2d_757[0][0]']
#  hNormalization)                )
#
#  activation_726 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1203[0][0]'
#                                 )                                ]
#
#  conv2d_758 (Conv2D)            (None, 256, 256, 32  9248        ['activation_726[0][0]']
#                                 )
#
#  batch_normalization_1204 (Batc  (None, 256, 256, 32  128        ['conv2d_758[0][0]']
#  hNormalization)                )
#
#  activation_727 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_1204[0][0]'
#                                 )                                ]
#
#  conv2d_759 (Conv2D)            (None, 256, 256, 2)  578         ['activation_727[0][0]']
#
# ==================================================================================================
# Total params: 16,958,530
# Trainable params: 16,944,834
# Non-trainable params: 13,696
# __________________________________________________________________________________________________
